# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#                                  region  municipality       oktmo  \
# 0      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  79701000.0
# 1      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  79701000.0
# 2      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  79701000.0
# 3      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  79701000.0
# 4      ru01 Республика Адыгея  (Адыгея)  Город Майкоп  79701000.0
# ...                                 ...           ...         ...
# 30497           ru50 Московская область   Одинцовский  46641000.0
# 30498           ru50 Московская область   Одинцовский  46641000.0
# 30499           ru50 Московская область   Одинцовский  46641000.0
# 30500           ru50 Московская область   Одинцовский  46641000.0
# 30501           ru50 Московская область   Одинцовский  46641000.0
#
#                                                 mun_type  year  \
# 0      Городской округ, городской округ с внутригород...  2006
# ...

# %%
data.model.isnull().sum()
# Out:
# 961

# %%
def analyse_change(mun_df):
    """определяет тип муниципалитета по отношению к тритменту, где тритмент - переход из избираемых в назначаемые или менеджеры

       returns
       type: str

       возможные типы:
       T = treated
       DT = сначала сити-менеджер, а потом - назначаемый мэр (например, Одинцовский район)
       TR = treated and returned
       NT = never treated
       NA = есть пропуски
    """
model_hist = mun_df

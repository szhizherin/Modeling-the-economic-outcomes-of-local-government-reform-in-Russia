# %%
import pandas as pd

from geonorm.geonormaliser_utils import get_standard
from geonorm.geonormaliser_utils import decompose
from geonorm.geomatch import Geomatch
from geonorm.geonormaliser import Geonormaliser

# %%
standard_df = pd.read_csv('mun_obr.csv', delimiter=';')

# %%
standard_df = standard_df[standard_df.lvl == 1]

# %%
openness = pd.read_excel("raw_openness.xlsx")

# %%
mun_names = openness["municipality"].unique()

# %%
mun_names = list(map(lambda x: x.replace('"', '').replace("'", ""), mun_names)) # remove quotes

# %%
def split_municipality_region(line):
    if "республики северная осетия-алания" in line.lower():
        mun = line[:-33].lower()
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return ["республики северная осетия-алания", mun]
    
    if "республики саха (якутия)" in line.lower():
        mun = line[:-24].lower()
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return ["республики саха (якутия)", mun]
    
    if "липецкой области российской федерации" in line.lower():
        mun = line[:-37].lower()
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return ["липецкой области", mun]
    
    if "еврейской автономной области" in line.lower():
        mun = line[:-28].lower()
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return ["еврейской автономной области", mun]
    
    if "ненецкого автономного округа" in line.lower():
        mun = line[:-28].lower()
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return ["ненецкого автономного округа", mun]
    
    if "ненецкого автономного округа" in line.lower():
        mun = line[:-28].lower()
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return ["ненецкого автономного округа", mun]
    
    if "Ханты-Мансийский автономный округ - Югра" in line:
        return [line, ""]
    
    if "Ямало-Ненецкий автономный округ" in line:
        return [line, ""]
    
    reg = line[line[:line.rfind(" ")].rfind(" "):].lower()
    mun = line[:line[:line.rfind(" ")].rfind(" ")].lower()
    if "области" in reg or "республики" in reg or "края" in reg:
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return [reg, mun]
    else:
        mun = line.lower()
        mun = mun.replace("муниципальное образование", "")
        mun = mun.replace("закрытое административно-территориальное образование", "ЗАТО")
        mun = mun.replace("закрытое административно -территориальное образование", "ЗАТО")
        return ["", mun]

# %%
mun_names = list(map(split_municipality_region, mun_names))

# %%
mun_names
# Out:
# [['', ' городской округ ногликский'],
#  [' сахалинской области', 'корсаковский городской округ'],
#  [' сахалинской области', 'макаровский городской округ'],
#  [' сахалинской области', 'тымовский городской округ'],
#  [' карачаево-черкесской республики', 'абазинский муниципальный район'],
#  ['', 'абанский район'],
#  ['', 'абатский муниципальный район'],
#  [' оренбургской области', 'абдулинский'],
#  [' республики башкортостан', 'абзелиловский район'],
#  ['', 'агаповский муниципальный район'],
#  ['', 'агрызский муниципальный район'],
#  ['', 'агульский район'],
#  [' оренбургской области', 'адамовский район'],
#  [' карачаево-черкесской республики', 'адыге-хабльский муниципальный район'],
#  ['', 'азнакаевский муниципальный район'],
#  [' омской области', 'азовский немецкий национальный муниципальный район'],
#  ['', 'азовский район'],
#  [' оренбургской области', 'акбулакский район'],
#  ['', 'аксайский район'],
#  ['', 'аксубаевский муниципальный район'],
#  ['', 'актанышский муниципальный район'],
#  ['', 'акушинский район'],
#  ['республики северная осетия-алания', 'алагирский район '],
#  [' чувашской республики', 'алатырский район'],
#  [' алтайского края', 'алейский район'],
#  ['', 'александро-невский муниципальный район'],
#  [' саратовской области', 'александрово-гайский муниципальный район'],
#  [' оренбургской области', 'александровский район'],
#  [' томской области', 'александровский район'],
#  ['', 'алексеевский муниципальный район'],
#  [' волгоградской области', 'алексеевский муниципальный район'],
#  ['', 'алексеевский муниципальный район и город алексеевка'],
#  ['', 'алеутский муниципальный округ'],
#  [' чувашской республики', 'аликовский район'],
#  ['', 'аллаиховский улус (район)'],
#  ['', 'алнашский район'],
#  [' алтайского края', 'алтайский район'],
#  [' республики хакасия', 'алтайский район'],
#  ['', 'алькеевский муниципальный район'],
#  [' курганской области', 'альменевский район'],
#  ['', 'альметьевский муниципальный район'],
#  [' республики башкортостан', 'альшеевский район'],
#  ['', 'амгинский улус (район)'],
#  ['', 'амурский муниципальный район'],
#  ['', 'анабарский национальный (долгано эвенкийский) улус (район)'],
#  ['', 'ангарское городское '],
#  ['', 'анжеро-судженский городской округ'],
#  ['', 'анивский городской округ'],
#  [' воронежской области', 'аннинский муниципальный район'],
#  [' костромской области', 'антроповский муниципальный район'],
#  ['', 'апастовский муниципальный район'],
#  ['', 'арамильский городской округ'],
#  ['', 'аргаяшский муниципальный район'],
#  ['', 'ардатовский муниципальный район'],
#  [' республики мордовия', 'ардатовский муниципальный район'],
#  ['республики северная осетия-алания', 'ардонский район '],
#  ['', 'арзамасский муниципальный район'],
#  ['', 'армизонский муниципальный район'],
#  ['', 'аромашевский муниципальный район'],
#  ['', 'арсеньевский городской округ'],
#  ['', 'арский муниципальный район'],
#  ['', 'артемовский городской округ'],
#  ['', 'артинский городской округ'],
#  [' республики башкортостан', 'архангельский район'],
#  ['', 'архаринский район'],
#  ['', 'асбестовский городской округ'],
#  [' оренбургской области', 'асекеевский район'],
#  [' томской области', 'асиновский район'],
#  [' республики хакасия', 'аскизский район'],
#  [' республики башкортостан', 'аскинский район'],
#  [' саратовской области', 'аткарский муниципальный район'],
#  ['', 'атнинский муниципальный район'],
#  [' республики мордовия', 'атюрьевский муниципальный район'],
#  [' республики мордовия', 'атяшевский муниципальный район'],
#  [' республики башкортостан', 'аургазинский район'],
#  ['', 'ахвахский район'],
#  ['', 'ахтубинский район'],
#  ['', 'ахтынский район'],
#  ['', 'ачинский район'],
#  ['', 'ачитский городской округ'],
#  ['', 'ачхой-мартановский муниципальный район'],
#  ['', 'ашинский муниципальный район'],
#  ['', 'аяно-майский муниципальный район'],
#  [' тверской области', 'бежецкий район'],
#  [' тверской области', 'бельский район'],
#  [' тверской области', 'бологовский район'],
#  [' вологодской области', 'бабаевский муниципальный район'],
#  ['', 'бабаюртовский район'],
#  [' вологодской области', 'бабушкинский муниципальный район'],
#  ['', 'бавлинский муниципальный район'],
#  ['', 'багаевский район'],
#  [' новосибирской области', 'баганский муниципальный район'],
#  [' алтайского края', 'баевский район'],
#  [' саратовской области', 'базарно-карабулакский муниципальный район'],
#  [' ульяновской области', 'базарносызганский район'],
#  ['', 'бай-тайгинский'],
#  ['', 'байкаловский муниципальный район'],
#  [' республики башкортостан', 'баймакский район'],
#  [' республики башкортостан', 'бакалинский район'],
#  ['', 'баксанский муниципальный район'],
#  [' томской области', 'бакчарский район'],
#  [' саратовской области', 'балаковский муниципальный район'],
#  ['', 'балахнинский муниципальный округ'],
#  ['', 'балахтинский район'],
#  ['', 'балашовский муниципальный район'],
#  ['', 'балезинский район'],
#  [' саратовской области', 'балтайский муниципальный район'],
#  ['', 'балтасинский муниципальный район'],
#  [' республики башкортостан', 'балтачевский район'],
#  [' новосибирской области', 'барабинский муниципальный район'],
#  ['', 'баргузинский район'],
#  ['', 'барун-хемчикский муниципиальный район'],
#  [' ульяновской области', 'барышский район'],
#  ['', 'батецкий муниципальный район'],
#  [' чувашской республики', 'батыревский район'],
#  ['', 'баунтовский эвенкийский район'],
#  [' пензенской области', 'башмаковский район'],
#  ['', 'бежаницкий район'],
#  [' республики хакасия', 'бейский район'],
#  [' пензенской области', 'бековский район'],
#  [' республики башкортостан', 'белебеевский район'],
#  [' пензенской области', 'белинский район'],
#  ['', 'беловский городской округ'],
#  ['', 'беловский муниципальный район'],
#  [' курской области', 'беловский район'],
#  ['', 'белогорский муниципальный округ'],
#  [' вологодской области', 'белозерский муниципальный район'],
#  [' курганской области', 'белозерский район'],
#  ['', 'белокалитвинский район'],
#  [' республики башкортостан', 'белокатайский район'],
#  ['', 'беломорский муниципальный район'],
#  [' республики башкортостан', 'белорецкий район'],
#  ['', 'белоярский городской округ'],
#  [' оренбургской области', 'беляевский район'],
#  ['', 'бердюжский муниципальный район'],
#  ['', 'березовский городской округ'],
#  ['', 'березовский район'],
#  [' пензенской области', 'бессоновский район'],
#  [' республики башкортостан', 'бижбулякский район'],
#  [' алтайского края', 'бийский район'],
#  ['', 'бикинский муниципальный район'],
#  ['', 'бирилюсский район'],
#  ['еврейской автономной области', 'биробиджанский муниципальный район '],
#  [' республики башкортостан', 'бирский район'],
#  ['', 'бисертский городской округ'],
#  ['', 'бичурский район'],
#  [' республики башкортостан', 'благоварский район'],
#  ['', 'благовещенский район'],
#  [' алтайского края', 'благовещенский район'],
#  [' республики башкортостан', 'благовещенский район'],
#  [' ставропольского края', 'благодарненский городской округ'],
#  [' воронежской области', 'бобровский муниципальный район'],
#  ['', 'богородский городской округ'],
#  ['', 'богородский муниципальный округ'],
#  ['', 'боготольский район'],
#  [' республики хакасия', 'боградский район'],
#  ['', 'богучанский район'],
#  [' воронежской области', 'богучарский муниципальный район'],
#  ['', 'боковский район'],
#  [' ленинградской области', 'бокситогорский муниципальный район'],
#  [' новосибирской области', 'болотнинский муниципальный район'],
#  [' орловской области', 'болховский муниципальный район'],
#  [' республики мордовия', 'большеберезниковский муниципальный район'],
#  ['', 'большеболдинский муниципальный район'],
#  [' республики мордовия', 'большеигнатовский муниципальный район'],
#  ['', 'большемурашкинский муниципальный район'],
#  ['', 'большемуртинский район'],
#  [' омской области', 'большереченский муниципальный район'],
#  [' ярославской области', 'большесельский муниципальный район'],
#  [' курской области', 'большесолдатский район'],
#  ['', 'большесосновский муниципальный район'],
#  ['', 'большеуковский муниципальный район'],
#  ['', 'большеулуйский район'],
#  ['', 'бондарский район'],
#  [' воронежской области', 'борисоглебский городской округ'],
#  [' ярославской области', 'борисоглебский муниципальный район'],
#  ['', 'боровичский муниципальный район'],
#  ['', 'ботлихский район'],
#  ['', 'брасовский район'],
#  ['', 'брединский муниципальный район'],
#  [' ярославской области', 'брейтовский муниципальный район'],
#  ['', 'брянский муниципальный район'],
#  ['', 'бугульминский муниципальный район'],
#  [' оренбургской области', 'бугурусланский район'],
#  [' республики башкортостан', 'буздякский район'],
#  [' оренбургской области', 'бузулукский район'],
#  ['', 'буинский муниципальный район'],
#  ['', 'буйнакский район'],
#  [' костромской области', 'буйский муниципальный район'],
#  [' республики башкортостан', 'бураевский район'],
#  ['', 'бурейский район'],
#  [' республики башкортостан', 'бурзянский район'],
#  [' алтайского края', 'бурлинский район'],
#  [' воронежской области', 'бутурлиновский муниципальный район'],
#  ['', 'бутурлинский муниципальный округ'],
#  [' волгоградской области', 'быковский муниципальный район'],
#  ['', 'быстринский муниципальный район'],
#  [' алтайского края', 'быстроистокский район'],
#  [' тверской области', 'вышневолоцкий городской округ'],
#  ['', 'вавожский район'],
#  ['', 'вагайский муниципальный район'],
#  [' пензенской области', 'вадинский район'],
#  ['', 'вадский муниципальный округ'],
#  ['', 'валдайский муниципальный район'],
#  ['', 'ванинский муниципальный район'],
#  [' курганской области', 'варгашинский район'],
#  ['', 'варнавинский муниципальный район'],
#  ['', 'варненский муниципальный район'],
#  ['', 'вачский муниципальный район'],
#  [' вологодской области', 'вашкинский муниципальный район'],
#  ['', 'веденский муниципальный район'],
#  ['', 'великолукский район'],
#  [' вологодской области', 'великоустюгский муниципальный район'],
#  ['', 'вельский муниципальный район'],
#  [' новосибирской области', 'венгеровский муниципальный район'],
#  [' пермского края', 'верещагинский городской округ'],
#  ['', 'верхнебуреинский муниципальный район'],
#  ['', 'верхневилюйский улус (район)'],
#  ['', 'верхнедонской район'],
#  [' томской области', 'верхнекетский район'],
#  ['', 'верхнеколымский улус (район)'],
#  [' ивановской области', 'верхнеландеховский муниципальный район'],
#  [' воронежской области', 'верхнемамонский муниципальный район'],
#  ['', 'верхнесалдинский городской округ'],
#  ['', 'верхнетоемский муниципальный район'],
#  ['', 'верхнеуральский муниципальный район'],
#  ['', 'верхнеуслонский муниципальный район'],
#  ['', 'верхнеуфалейский городской округ'],
#  [' воронежской области', 'верхнехавский муниципальный район'],
#  [' вологодской области', 'верховажский муниципальный район'],
#  [' орловской области', 'верховский район'],
#  ['', 'верхоянский район'],
#  ['', 'веселовский район'],
#  ['', 'ветлужский муниципальный район'],
#  [' ульяновской области', 'вешкаймский район'],
#  ['', 'викуловский муниципальный район'],
#  [' архангельской области', 'вилегодский муниципальный округ'],
#  ['', 'вилюйский улус (район)'],
#  ['', 'вилючинский городской округ ЗАТО город вилючинск'],
#  ['', 'виноградовский муниципальный район'],
#  [' ивановской области', 'вичугский муниципальный район'],
#  ['', 'владивостокский городской округ'],
#  [' вологодской области', 'вожегодский муниципальный района'],
#  ['', 'вознесенский муниципальный район'],
#  ['', 'волгодонской район'],
#  ['', 'волжский муниципальный район'],
#  ['липецкой области', 'воловский муниципальный район '],
#  ['', 'вологодский муниципальный район'],
#  ['', 'володарский муниципальный район'],
#  ['', 'володарский район'],
#  ['', 'волоколамский городской округ'],
#  ['', 'волотовский муниципальный округ'],
#  [' ленинградской области', 'волховский муниципальный район'],
#  ['', 'волчанский городской округ'],
#  [' алтайского края', 'волчихинский район'],
#  [' саратовской области', 'вольский муниципальный район'],
#  [' воронежской области', 'воробьёвский муниципальный район'],
#  ['', 'воскресенский муниципальный район'],
#  ['', 'воткинский район'],
#  [' костромской области', 'вохомский муниципальный район'],
#  [' чувашской республики', 'вурнарский район'],
#  ['', 'выгоничский муниципальный район'],
#  ['', 'высокогорский муниципальный район'],
#  [' вологодской области', 'вытегорский муниципальный район'],
#  ['', 'вяземский муниципальный район'],
#  [' тверской области', 'город кимры'],
#  [' тверской области', 'город ржев'],
#  [' тверской области', 'город тверь'],
#  [' тверской области', 'город торжок'],
#  [' ярославской области', 'гаврилов-ямский муниципальный район'],
#  [' ивановской области', 'гаврилово-посадский муниципальный район'],
#  ['', 'гавриловский район'],
#  ['', 'гагинский муниципальный район'],
#  [' костромской области', 'галичский муниципальный район'],
#  ['', 'гаринский городской округ'],
#  [' республики башкортостан', 'гафурийский район'],
#  ['', 'гдовский район'],
#  [' ставропольского края', 'георгиевский городской округ'],
#  ['', 'гергебильский район'],
#  ['', 'глазовский район'],
#  [' орловской области', 'глазуновский район'],
#  [' курской области', 'глушковский район'],
#  ['', 'голышмановский городской округ'],
#  ['', 'гордеевский муниципальный район'],
#  ['', 'горнозаводский городской округ'],
#  ['', 'горномарийский муниципальный район'],
#  ['', 'горноуральский городской округ'],
#  ['', 'город азов'],
#  [' чувашской республики', 'город алатырь'],
#  ['', 'город архангельск, городской округ'],
#  ['', 'город астрахань'],
#  ['', 'город батайск'],
#  ['еврейской автономной области', 'город биробиджан '],
#  [' оренбургской области', 'город бузулук'],
#  ['', 'город великие луки'],
#  ['', 'город волгодонск'],
#  ['', 'город воткинск'],
#  ['', 'город глазов'],
#  ['', 'город гуково'],
#  ['', 'город донецк'],
#  [' курской области', 'город железногорск'],
#  ['', 'город зверево'],
#  ['', 'город ижевск'],
#  ['', 'город каменск-уральский'],
#  ['', 'город каменск-шахтинский'],
#  [' томской области', 'город кедровый'],
#  ['', 'город кирсанов'],
#  ['', 'город коряжма, городской округ'],
#  ['', 'город котовск'],
#  [' курской области', 'город курск'],
#  [' курской области', 'город курчатов'],
#  [' орловской области', 'город ливны'],
#  ['', 'город можга'],
#  ['', 'город моршанск'],
#  [' орловской области', 'город мценск'],
#  ['', 'город нижний тагил'],
#  ['', 'город новодвинск, городской округ'],
#  [' чувашской республики', 'город новочебоксарск'],
#  ['', 'город новочеркасск'],
#  ['', 'город новошахтинск'],
#  [' новосибирской области', 'город обь'],
#  ['', 'город псков'],
#  ['', 'город рассказово'],
#  ['', 'город ростов-на-дону'],
#  ['', 'город сарапул'],
#  [' томской области', 'город стрежевой'],
#  ['', 'город таганрог'],
#  ['', 'город тамбов'],
#  [' томской области', 'город томск'],
#  ['', 'город уварово'],
#  ['', 'город чебоксары'],
#  [' вологодской области', 'город череповец'],
#  ['', 'город шахты'],
#  [' чувашской республики', 'город шумерля'],
#  ['', 'городецкий муниципальный район'],
#  [' волгоградской области', 'городищенский муниципальный район'],
#  [' пензенской области', 'городищенский район'],
#  [' республики калмыкия', 'городовиковское районное '],
#  [' белгородской области', 'городской округ город белгород'],
#  ['', 'городской округ город волжск'],
#  ['', 'городской округ город йошкар-ола'],
#  ['', 'городской округ город калуга'],
#  ['', 'городской округ город козьмодемьянск'],
#  ['', 'городской округ город лесной'],
#  ['ненецкого автономного округа', 'городской округ город нарьян-мар '],
#  ['', 'городской округ город обнинск'],
#  ['', 'городской округ город якутск'],
#  ['республики саха (якутия)', 'городской округ жатай '],
#  [' волгоградской области', 'городской округ - город волжский'],
#  [' волгоградской области', 'городской округ - город камышин'],
#  ['', 'городской округ - город кудымкар'],
#  [' волгоградской области', 'городской округ - город михайловка'],
#  [' волгоградской области', 'городской округ - город урюпинск'],
#  [' волгоградской области', 'городской округ - город фролово'],
#  ['', 'городской округ балашиха'],
#  ['', 'городской округ богданович'],
#  ['', 'городской округ большой камень'],
#  ['', 'городской округ бронницы'],
#  ['', 'городской округ великий новгород'],
#  ['', 'городской округ верх-нейвинский'],
#  ['', 'городской округ верхнее дуброво'],
#  ['', 'городской округ верхний тагил'],
#  ['', 'городской округ верхняя пышма'],
#  ['', 'городской округ верхняя тура'],
#  ['', 'городской округ верхотурский'],
#  ['', 'городской округ вичуга'],
#  ['', 'городской округ дегтярск'],
#  ['', 'городской округ дзержинский'],
#  ['', 'городской округ долгопрудный'],
#  ['', 'городской округ домодедово'],
#  ['', 'городской округ дубна'],
#  ['', 'городской округ егорьевск'],
#  ['', 'городской округ жуковский'],
#  ['', 'городской округ зато свободный'],
#  ['', 'городской округ зато город фокино'],
#  ['', 'городской округ зарайск'],
#  ['', 'городской округ заречный'],
#  ['', 'городской округ иваново'],
#  ['', 'городской округ ивантеевка'],
#  ['', 'городской округ истра'],
#  ['', 'городской округ карпинск'],
#  ['', 'городской округ кашира'],
#  ['', 'городской округ кинешма'],
#  ['', 'городской округ клин'],
#  ['', 'городской округ королев'],
#  ['', 'городской округ котельники'],
#  ['', 'городской округ кохма'],
#  ['', 'городской округ красноармейск'],
#  ['', 'городской округ красногорск'],
#  ['', 'городской округ краснознаменск'],
#  ['', 'городской округ краснотурьинск'],
#  ['', 'городской округ красноуральск'],
#  ['', 'городской округ красноуфимск'],
#  ['', 'городской округ лобня'],
#  ['', 'городской округ лосино-петровский'],
#  ['', 'городской округ луховицы'],
#  ['', 'городской округ люберцы'],
#  ['', 'городской округ молодежный'],
#  ['', 'городской округ мытищи'],
#  ['', 'городской округ нижняя салда'],
#  ['', 'городской округ озеры'],
#  ['', 'городской округ орехово-зуево'],
#  ['', 'городской округ павловский посад'],
#  ['', 'городской округ пелым'],
#  ['', 'городской округ первоуральск'],
#  ['', 'городской округ пущино'],
#  ['', 'городской округ ревда'],
#  ['', 'городской округ реутов'],
#  ['', 'городской округ рефтинский'],
#  ['', 'городской округ серебряные пруды'],
#  ['', 'городской округ серпухов'],
#  ['', 'городской округ спасск-дальний'],
#  ['', 'городской округ среднеуральск'],
#  ['', 'городской округ староуткинск'],
#  ['', 'городской округ ступино'],
#  ['', 'городской округ сухой лог'],
#  ['', 'городской округ тейково'],
#  ['', 'городской округ фрязино'],
#  ['', 'городской округ химки'],
#  ['', 'городской округ черноголовка'],
#  ['', 'городской округ чехов'],
#  ['', 'городской округ шатура'],
#  ['', 'городской округ шаховская'],
#  ['', 'городской округ шуя'],
#  ['', 'городской округ электрогорск'],
#  ['республики северная осетия-алания', 'городской округ г. владикавказ '],
#  ['', 'городской округ город аргун'],
#  [' воронежской области', 'городской округ город воронеж'],
#  ['', 'городской округ город грозный'],
#  ['липецкой области', 'городской округ город елец '],
#  ['', 'городской округ город карабулак'],
#  ['липецкой области', 'городской округ город липецк '],
#  ['', 'городской округ город магас'],
#  ['', 'городской округ город малгобек'],
#  ['', 'городской округ город назрань'],
#  [' воронежской области', 'городской округ город нововоронеж'],
#  [' омской области', 'городской округ город омск'],
#  ['', 'городской округ город сунжа'],
#  ['', 'городской округ город-герой волгоград'],
#  ['', 'городской округ-город элиста'],
#  [' курской области', 'горшеченский район'],
#  [' омской области', 'горьковский муниципальный район'],
#  ['', 'граховский район'],
#  [' оренбургской области', 'грачёвский район'],
#  ['', 'гремячинский городской округ'],
#  [' воронежской области', 'грибановский муниципальный район'],
#  ['', 'грозненский муниципальный район'],
#  ['липецкой области', 'грязинский муниципальный район '],
#  [' вологодской области', 'грязовецкий муниципальный район'],
#  [' белгородской области', 'губкинский городской округ'],
#  ['', 'гудермесский муниципальный район'],
#  ['', 'гумбетовский район'],
#  ['', 'гунибский район'],
#  [' республики башкортостан', 'давлекановский район'],
#  [' курганской области', 'далматовский район'],
#  ['', 'дальнегорский городской округ'],
#  ['', 'дальнеконстантиновский муниципальный район'],
#  ['', 'дальнереченский городской округ'],
#  ['', 'дальнереченский муниципальный район'],
#  [' волгоградской области', 'даниловский муниципальный район'],
#  [' ярославской области', 'даниловский муниципальный район'],
#  ['липецкой области', 'данковский муниципальный район '],
#  ['', 'дахадаевский район'],
#  ['', 'дебесский район'],
#  ['', 'дедовичский район'],
#  ['', 'демянский муниципальный район'],
#  ['', 'дербентский район'],
#  [' саратовской области', 'дергачевский муниципальный район'],
#  ['', 'джейрахский муниципальный район'],
#  ['', 'джидинский район'],
#  ['', 'дзержинский район'],
#  ['', 'дзун-хемчикский муниципиальный район'],
#  ['', 'дивеевский муниципальный округ'],
#  ['республики северная осетия-алания', 'дигорский район '],
#  [' курской области', 'дмитриевский район'],
#  ['', 'дмитровский городской округ'],
#  [' орловской области', 'дмитровский муниципальный район'],
#  ['', 'дновский район'],
#  ['липецкой области', 'добринский муниципальный район '],
#  ['липецкой области', 'добровский муниципальный район '],
#  ['', 'добрянский городской округ'],
#  [' новосибирской области', 'доволенский муниципальный район'],
#  ['', 'докузпаринский район'],
#  ['липецкой области', 'долгоруковский муниципальный район '],
#  [' орловской области', 'должанский район'],
#  [' оренбургской области', 'домбаровский район'],
#  ['', 'дрожжановский муниципальный район'],
#  [' республики мордовия', 'дубенский муниципальный район'],
#  [' волгоградской области', 'дубовский муниципальный район'],
#  ['', 'дубовский район'],
#  ['', 'дубровский район'],
#  [' республики башкортостан', 'дуванский район'],
#  [' саратовской области', 'духовницкий муниципальный район'],
#  [' республики башкортостан', 'дюртюлинский район'],
#  ['', 'дятьковский район'],
#  ['', 'егорлыкский район'],
#  [' алтайского края', 'егорьевский район'],
#  [' саратовской области', 'екатериновский муниципальный район'],
#  ['', 'елабужский муниципальный район'],
#  [' волгоградской области', 'еланский муниципальный район'],
#  ['липецкой области', 'елецкий муниципальный район '],
#  ['', 'елизовский муниципальный район'],
#  [' республики мордовия', 'ельниковский муниципальный район'],
#  [' алтайского края', 'ельцовский район'],
#  ['', 'еманжелинский муниципальный район'],
#  ['', 'емельяновский район'],
#  ['', 'енисейский район'],
#  ['', 'енотаевский район'],
#  ['', 'еравнинский район'],
#  ['', 'ермаковский район'],
#  [' республики башкортостан', 'ермекеевский район'],
#  [' рязанской области', 'ермишинский муниципальный район'],
#  [' саратовской области', 'ершовский муниципальный район'],
#  ['', 'еткульский муниципальный район'],
#  [' тверской области', 'жарковский район'],
#  [' курской области', 'железногорский район'],
#  ['', 'жердевский район'],
#  ['', 'жиганский улус'],
#  [' волгоградской области', 'жирновский муниципальный район'],
#  [' брянской области', 'жирятинский район'],
#  [' брянской области', 'жуковский муниципальный округ'],
#  [' тверской области', 'ЗАТО озерный'],
#  [' тверской области', 'ЗАТО солнечный'],
#  ['', 'зато город железногорск'],
#  [' пензенской области', 'зато город заречный'],
#  ['', 'зато город зеленогорск'],
#  ['', 'зато поселок солнечный'],
#  [' тверской области', 'зубцовский район'],
#  ['', 'заветинский район'],
#  ['', 'завитинский район'],
#  ['', 'заводоуковский городской округ'],
#  [' ивановской области', 'заволжский муниципальный район'],
#  ['', 'завьяловский район'],
#  [' алтайского края', 'завьяловский район'],
#  ['липецкой области', 'задонский муниципальный район '],
#  ['', 'заиграевский район'],
#  ['', 'заинский муниципальный район'],
#  ['', 'закаменский район'],
#  [' саратовской области', 'ЗАТО -поселок михайловский'],
#  [' саратовской области', 'ЗАТО -поселок светлый'],
#  ['', 'ЗАТО звездный'],
#  ['', 'ЗАТО знаменск'],
#  [' томской области', 'ЗАТО северск'],
#  [' саратовской области', 'ЗАТО шиханы'],
#  ['', 'ЗАТО город межгорье республики башкортостан городской округ'],
#  ['', 'ЗАТО город радужный'],
#  [' оренбургской области', 'ЗАТО поселок комаровский'],
#  [' орловской области', 'залегощенский район'],
#  [' алтайского края', 'залесовский район'],
#  [' алтайского края', 'заринский район'],
#  ['', 'захаровский муниципальный район'],
#  ['', 'звениговский муниципальный район'],
#  [' курганской области', 'звериноголовский район'],
#  [' новосибирской области', 'здвинский муниципальный район'],
#  ['', 'зейский район'],
#  ['', 'зеленодольский муниципальный район'],
#  [' карачаево-черкесской республики', 'зеленчукский муниципальный район'],
#  [' пензенской области', 'земетчинский район'],
#  ['', 'зерноградский район'],
#  [' республики башкортостан', 'зианчуринский район'],
#  [' республики башкортостан', 'зилаирский район'],
#  ['', 'зиминское городское '],
#  ['', 'зиминское районное '],
#  ['', 'зимовниковский район'],
#  ['', 'златоустовский городской округ'],
#  ['', 'злынковский район'],
#  [' алтайского края', 'змеиногорский район'],
#  [' омской области', 'знаменский муниципальный район'],
#  ['', 'знаменский район'],
#  [' орловской области', 'знаменский район'],
#  [' курской области', 'золотухинский район'],
#  ['', 'зольский муниципальный район'],
#  [' алтайского края', 'зональный район'],
#  [' республики мордовия', 'зубово-полянский муниципальный район'],
#  [' томской области', 'зырянский район'],
#  [' чувашской республики', 'ибресинский район'],
#  [' ивановской области', 'ивановский муниципальный район'],
#  ['', 'ивановский район'],
#  ['', 'ивантеевский муниципальный район'],
#  ['', 'ивдельский городской округ'],
#  ['', 'иволгинский район'],
#  [' республики башкортостан', 'иглинский район'],
#  ['', 'игринский район'],
#  ['', 'идринский район'],
#  ['липецкой области', 'измалковский муниципальный район '],
#  [' ставропольского края', 'изобильненский городской округ'],
#  [' республики калмыкия', 'ики-бурульское районное '],
#  ['', 'икрянинский район'],
#  ['', 'иланский район'],
#  [' оренбургской области', 'илекский муниципальный район'],
#  [' республики башкортостан', 'илишевский район'],
#  [' волгоградской области', 'иловлинский муниципальный район'],
#  ['', 'ильинский городской округ'],
#  [' ивановской области', 'ильинский муниципальный район'],
#  ['', 'инжавинский район'],
#  [' ульяновской области', 'инзенский район'],
#  [' республики мордовия', 'инсарский муниципальный район'],
#  [' ставропольского края', 'ипатовский городской округ'],
#  ['республики северная осетия-алания', 'ирафский район '],
#  ['', 'ирбейский район'],
#  ['', 'ирбитское '],
#  ['', 'иркутское районное '],
#  ['', 'исетский муниципальный район'],
#  [' омской области', 'исилькульский муниципальный район'],
#  [' новосибирской области', 'искитимский муниципальный район'],
#  [' пензенской области', 'иссинский район'],
#  ['', 'итум-калинский муниципальный район'],
#  [' республики мордовия', 'ичалковский муниципальный район'],
#  [' республики башкортостан', 'ишимбайский район'],
#  ['', 'ишимский муниципальный район'],
#  [' тверской области', 'калининский район'],
#  [' тверской области', 'калязинский район'],
#  [' тверской области', 'кашинский городской округ'],
#  [' тверской области', 'кесовогорский район'],
#  [' тверской области', 'кимрский район'],
#  [' тверской области', 'конаковский район'],
#  [' тверской области', 'кувшиновский район'],
#  ['', 'каа-хемский'],
#  ['', 'кабанский район'],
#  ['', 'кавалеровский муниципальный район'],
#  ['', 'кагальницкий район'],
#  ['', 'кадомский муниципальный район'],
#  [' республики мордовия', 'кадошкинский муниципальный район'],
#  [' вологодской области', 'кадуйский муниципальный район'],
#  [' костромской области', 'кадыйский муниципальный район'],
#  ['', 'казанский муниципальный район'],
#  ['', 'казачинский район'],
#  ['', 'казбековский район'],
#  ['', 'кайбицкий муниципальный район'],
#  ['', 'кайтагский район'],
#  [' забайкальского края', 'каларский муниципальный округ'],
#  [' волгоградской области', 'калачевский муниципальный район'],
#  [' воронежской области', 'калачеевский муниципальный район'],
#  [' омской области', 'калачинский муниципальный район'],
#  ['', 'калевальский муниципальный район'],
#  [' саратовской области', 'калининский муниципальный район'],
#  [' алтайского края', 'калманский район'],
#  ['', 'калтанский городской округ'],
#  [' республики башкортостан', 'калтасинский район'],
#  ['', 'камбарский район'],
#  ['', 'каменский городской округ'],
#  [' воронежской области', 'каменский муниципальный район'],
#  ['', 'каменский район'],
#  [' алтайского края', 'каменский район'],
#  [' пензенской области', 'каменский район'],
#  [' пензенской области', 'камешкирский район'],
#  ['', 'камско-устьинский муниципальный район'],
#  ['', 'камызякский район'],
#  [' волгоградской области', 'камышинский муниципальный район'],
#  ['', 'камышловский городской округ'],
#  ['', 'камышловский муниципальный район'],
#  [' чувашской республики', 'канашский район'],
#  ['', 'канский район'],
#  [' воронежской области', 'кантемировский муниципальный район'],
#  ['', 'карабашский городской округ'],
#  ['', 'карабудахкентский район'],
#  ['', 'карагинский муниципальный район'],
#  [' республики башкортостан', 'караидельский район'],
#  ['', 'каракулинский район'],
#  [' новосибирской области', 'карасукский муниципальный район'],
#  ['', 'каратузский район'],
#  [' карачаево-черкесской республики', 'карачаевский городской округ'],
#  [' карачаево-черкесской республики', 'карачаевский муниципальный район'],
#  ['', 'карачевский район'],
#  [' курганской области', 'каргапольский район'],
#  [' томской области', 'каргасокский район'],
#  [' новосибирской области', 'каргатский муниципальный район'],
#  [' архангельской области', 'каргопольский муниципальный округ'],
#  [' республики башкортостан', 'кармаскалинский район'],
#  [' ульяновской области', 'карсунский район'],
#  ['', 'карталинский муниципальный район'],
#  ['', 'касимовский муниципальный район'],
#  ['', 'каслинский муниципальный район'],
#  [' курской области', 'касторенский район'],
#  ['', 'катав-ивановский муниципальный район'],
#  [' курганской области', 'катайский район'],
#  ['', 'качканарский городской округ'],
#  ['', 'кашарский район'],
#  [' воронежской области', 'каширский муниципальный район'],
#  ['', 'каякентский район'],
#  [' оренбургской области', 'кваркенский район'],
#  ['', 'кежемский район'],
#  ['', 'кезский район'],
#  ['', 'кемеровский городской округ'],
#  ['', 'кемский муниципальный район'],
#  [' курганской области', 'кетовский район'],
#  [' республики калмыкия', 'кетченеровское районное '],
#  [' республики башкортостан', 'кигинский район'],
#  ['', 'кижингинский район'],
#  ['', 'кизильский муниципальный район'],
#  ['', 'кизилюртовский район'],
#  ['', 'кизлярский район'],
#  ['', 'кизнерский район'],
#  [' волгоградской области', 'киквидзенский муниципальный район'],
#  ['', 'килемарский муниципальный район'],
#  [' ивановской области', 'кинешемский муниципальный район'],
#  [' вологодской области', 'кирилловский муниципальный район'],
#  ['', 'кировградский городской округ'],
#  [' ставропольского края', 'кировский городской округ'],
#  ['', 'кировский муниципальный район'],
#  [' ленинградской области', 'кировский муниципальный район'],
#  ['республики северная осетия-алания', 'кировский район '],
#  ['', 'кирсановский район'],
#  ['', 'киселевский городской округ'],
#  [' вологодской области', 'кичменгско-городецкий муниципальный район'],
#  ['', 'киясовский район'],
#  ['', 'клепиковский муниципальный район'],
#  ['', 'клетнянский муниципальный район'],
#  [' волгоградской области', 'клетский муниципальный район'],
#  ['', 'климовский муниципальный район'],
#  ['', 'клинцовский район'],
#  [' алтайского края', 'ключевский район'],
#  ['', 'княгининский муниципальный район'],
#  ['республики саха (якутия)', 'кобяйский улус '],
#  ['', 'ковернинский муниципальный округ'],
#  [' республики мордовия', 'ковылкинский муниципальный район'],
#  [' томской области', 'кожевниковский район'],
#  [' чувашской республики', 'козловский район'],
#  ['', 'козульский район'],
#  ['', 'кологривский муниципальный округ'],
#  ['', 'коломенский городской округ'],
#  [' омской области', 'колосовский муниципальный район'],
#  [' томской области', 'колпашевский район'],
#  [' орловской области', 'колпнянский район'],
#  [' новосибирской области', 'колыванский муниципальный район'],
#  [' пензенской области', 'колышлейский район'],
#  [' брянской области', 'комаричский муниципальный район'],
#  ['', 'комсомольский муниципальный район'],
#  [' ивановской области', 'комсомольский муниципальный район'],
#  [' чувашской республики', 'комсомольский район'],
#  ['', 'кондопожский муниципальный район'],
#  ['', 'коношский муниципальный район'],
#  ['', 'константиновский район'],
#  [' курской области', 'конышевский район'],
#  ['', 'копейский городской округ'],
#  ['', 'кораблинский муниципальный район'],
#  [' курской области', 'кореневский район'],
#  ['', 'коркинский муниципальный район'],
#  [' омской области', 'кормиловский муниципальный район'],
#  [' орловской области', 'корсаковский район'],
#  [' алтайского края', 'косихинский район'],
#  ['', 'костомукшский городской округ'],
#  [' костромской области', 'костромской муниципальный район'],
#  [' волгоградской области', 'котельниковский муниципальный район'],
#  ['', 'котлас, городской округ'],
#  ['', 'котласский муниципальный район'],
#  [' волгоградской области', 'котовский муниципальный район'],
#  [' новосибирской области', 'коченевский муниципальный район'],
#  [' новосибирской области', 'кочковский муниципальный район'],
#  [' республики мордовия', 'кочкуровский муниципальный район'],
#  ['липецкой области', 'краснинский муниципальный район '],
#  ['', 'красноармейский муниципальный район'],
#  [' чувашской республики', 'красноармейский район'],
#  ['', 'краснобаковский муниципальный район'],
#  ['', 'красноборский муниципальный район'],
#  ['', 'краснобродский городской округ'],
#  ['', 'красновишерский городской округ'],
#  [' оренбургской области', 'красногвардейский район'],
#  ['', 'красногородский район'],
#  ['', 'красногорский район'],
#  [' алтайского края', 'красногорский район'],
#  [' новосибирской области', 'краснозерский муниципальный район'],
#  [' орловской области', 'краснозоренский район'],
#  ['', 'краснокамский городской округ'],
#  [' республики башкортостан', 'краснокамский район'],
#  [' саратовской области', 'краснокутский муниципальный район'],
#  ['', 'краснооктябрьский муниципальный район'],
#  ['', 'красноселькупский район'],
#  [' костромской области', 'красносельский муниципальный район'],
#  [' республики мордовия', 'краснослободский муниципальный район'],
#  ['', 'красносулинский район'],
#  ['', 'краснотуранский район'],
#  [' чувашской республики', 'красночетайский район'],
#  [' алтайского края', 'краснощёковский район'],
#  ['', 'красноярский район'],
#  ['', 'крестецкий муниципальный район'],
#  [' томской области', 'кривошеинский район'],
#  [' орловской области', 'кромской муниципальный район'],
#  [' омской области', 'крутинский муниципальный район'],
#  [' алтайского края', 'крутихинский район'],
#  ['', 'кстовский муниципальный район'],
#  [' оренбургской области', 'кувандыкский'],
#  [' республики башкортостан', 'кугарчинский район'],
#  ['', 'куженерский муниципальный район'],
#  [' пензенской области', 'кузнецкий район'],
#  [' ульяновской области', 'кузоватовский район'],
#  [' новосибирской области', 'куйбышевский муниципальный район'],
#  ['', 'куйбышевский район'],
#  ['', 'кукморский муниципальный район'],
#  ['', 'кулинский район'],
#  [' алтайского края', 'кулундинский район'],
#  ['', 'кумторкалинский район'],
#  [' волгоградской области', 'кумылженский муниципальный район'],
#  ['', 'кунашакский муниципальный район'],
#  ['', 'кунгурский муниципальный район'],
#  ['', 'куньинский район'],
#  [' новосибирской области', 'купинский муниципальный район'],
#  ['', 'курагинский район'],
#  ['', 'курахский район'],
#  ['', 'курильский городской округ'],
#  [' оренбургской области', 'курманаевский район'],
#  [' курской области', 'курский район'],
#  [' курганской области', 'куртамышский район'],
#  ['', 'курумканский район'],
#  ['', 'курчалоевский муниципальный район'],
#  [' курской области', 'курчатовский район'],
#  [' алтайского края', 'курьинский район'],
#  ['', 'кусинский муниципальный район'],
#  ['', 'кушвинский городской округ'],
#  [' республики башкортостан', 'кушнаренковский район'],
#  [' республики башкортостан', 'куюргазинский район'],
#  ['', 'кызылский район'],
#  [' алтайского края', 'кытмановский район'],
#  [' новосибирской области', 'кыштовский муниципальный район'],
#  ['', 'кыштымский городской округ'],
#  ['', 'кяхтинский район'],
#  [' тверской области', 'лихославльский район'],
#  [' республики калмыкия', 'лаганское районное '],
#  ['', 'лазовский муниципальный район'],
#  ['', 'лаишевский муниципальный район'],
#  ['', 'лакский район'],
#  ['', 'лахденпохский муниципальный район'],
#  ['липецкой области', 'лебедянский муниципальный район '],
#  [' курганской области', 'лебяжьевский район'],
#  ['липецкой области', 'лев-толстовский муниципальный район '],
#  ['', 'левашинский район'],
#  [' ивановской области', 'лежневский муниципальный район'],
#  ['', 'лениногорский муниципальный район'],
#  ['', 'ленинск-кузнецкий городской округ'],
#  ['', 'ленинский городской округ'],
#  [' волгоградской области', 'ленинский муниципальный район'],
#  ['еврейской автономной области', 'ленинский муниципальный район '],
#  ['', 'ленский район муниципальный район'],
#  ['', 'лескенский муниципальный район'],
#  ['', 'лесозаводский городской округ'],
#  ['', 'лешуконский муниципальный район'],
#  [' орловской области', 'ливенский район'],
#  ['', 'лиманский район'],
#  ['липецкой области', 'липецкий муниципальный район '],
#  [' воронежской области', 'лискинский муниципальный район'],
#  ['', 'локнянский район'],
#  ['', 'локомотивный городской округ'],
#  [' алтайского края', 'локтевский район'],
#  [' пензенской области', 'лопатинский район'],
#  ['', 'лоухский муниципальный район'],
#  [' ленинградской области', 'лужский муниципальный район'],
#  ['', 'лукояновский муниципальный район'],
#  [' пензенской области', 'лунинский район'],
#  [' ивановской области', 'лухский муниципальный район'],
#  ['', 'лысковский муниципальный округ'],
#  [' саратовской области', 'лысогорский муниципальный район'],
#  ['', 'лысьвенский городской округ'],
#  [' курской области', 'льговский район'],
#  [' ярославской области', 'любимский муниципальный район'],
#  [' омской области', 'любинский муниципальный район'],
#  ['', 'любытинский муниципальный район'],
#  [' республики мордовия', 'лямбирский муниципальный район'],
#  [' тверской области', 'максатихинский район'],
#  ['', 'мо арсеньевский район'],
#  ['', 'мо белевский район'],
#  ['', 'мо богородицкий район'],
#  ['', 'мо веневский район'],
#  ['', 'мо воловский район'],
#  ['', 'мо дубенский район'],
#  ['', 'мо заокский район'],
#  ['', 'мо каменский район'],
#  ['', 'мо кимовский район'],
#  ['', 'мо киреевский район'],
#  ['', 'мо куркинский район'],
#  ['', 'мо одоевский район'],
#  ['', 'мо плавский район'],
#  ['', 'мо суворовский район'],
#  ['', 'мо тепло-огаревский район'],
#  ['', 'мо узловский район'],
#  ['', 'мо чернский район'],
#  ['', 'мо щекинский район'],
#  ['', 'мо ясногорский район'],
#  ['', 'мо г. ефремов'],
#  ['', 'мо г. новомосковск'],
#  ['', 'мо г. тула'],
#  ['', 'мо г.алексин'],
#  ['', 'мо г.донской'],
#  ['', 'мо пгт славный'],
#  ['', 'мо рп новогуровский'],
#  [' тверской области', 'молоковский район'],
#  [' ставропольского края', 'муниципальные округа'],
#  ['', 'магарамкентский район'],
#  ['', 'магдагачинский район'],
#  ['', 'магнитогорский городской округ'],
#  ['', 'мазановский район'],
#  [' ульяновской области', 'майнский район'],
#  ['', 'майский муниципальный район'],
#  [' костромской области', 'макарьевский муниципальный район'],
#  [' курганской области', 'макушинский муниципальный округ'],
#  [' карачаево-черкесской республики', 'малакарачаевский муниципальный район'],
#  ['', 'малгобекский муниципальный район'],
#  [' орловской области', 'малоархангельский муниципальный район'],
#  ['', 'маловишерский муниципальный район'],
#  [' республики калмыкия', 'малодербетовское районное '],
#  ['', 'малопургинский район'],
#  [' пензенской области', 'малосердобинский район'],
#  ['', 'малышевский городской округ'],
#  ['', 'мамадышский муниципальный район'],
#  [' алтайского края', 'мамонтовский район'],
#  ['', 'манский район'],
#  [' курской области', 'мантуровский район'],
#  ['', 'мари-турекский муниципальный район'],
#  ['', 'мариинский муниципальный район'],
#  [' чувашской республики', 'мариинско - посадский район'],
#  [' саратовской области', 'марксовский муниципальный район'],
#  ['', 'мартыновский район'],
#  [' омской области', 'марьяновский муниципальный район'],
#  ['', 'марёвский муниципальный округ'],
#  [' новосибирской области', 'маслянинский муниципальный район'],
#  ['', 'матвеево-курганский район'],
#  [' оренбургской области', 'матвеевский район'],
#  ['', 'махнёвское '],
#  ['', 'мглинский район'],
#  ['', 'мегино-кангаласский улус'],
#  ['', 'медведевский муниципальный район'],
#  ['', 'медвежьегорский муниципальный район'],
#  [' курской области', 'медвенский район'],
#  ['', 'междуреченский городской округ'],
#  [' вологодской области', 'междуреченский муниципальный район'],
#  ['', 'межевской муниципальный округ'],
#  ['', 'мезенский муниципальный район'],
#  [' ульяновской области', 'мелекесский район'],
#  [' республики башкортостан', 'мелеузовский район'],
#  ['', 'менделеевский муниципальный район'],
#  ['', 'мензелинский муниципальный район'],
#  [' республики башкортостан', 'мечетлинский район'],
#  ['', 'миасский городской округ'],
#  ['', 'миллеровский район'],
#  ['', 'милославский муниципальный район'],
#  ['', 'мильковский муниципальный район'],
#  ['', 'милютинский район'],
#  [' ставропольского края', 'минераловодский городской округ'],
#  ['', 'минусинский район'],
#  ['', 'мирный, городской округ'],
#  ['', 'михайловский муниципальный район'],
#  ['', 'михайловский район'],
#  [' алтайского края', 'михайловский район'],
#  ['', 'мичуринский район'],
#  [' курганской области', 'мишкинский район'],
#  [' республики башкортостан', 'мишкинский район'],
#  [' республики башкортостан', 'миякинский район'],
#  ['', 'можайский городской округ'],
#  ['республики северная осетия-алания', 'моздокский район '],
#  [' курганской области', 'мокроусовский район'],
#  [' пензенской области', 'мокшанский район'],
#  [' томской области', 'молчановский район'],
#  ['', 'монгун-тайгинский'],
#  [' чувашской республики', 'моргаушский район'],
#  ['', 'мордовский район'],
#  ['', 'моркинский муниципальный район'],
#  ['', 'морозовский район'],
#  ['', 'моршанский район'],
#  [' омской области', 'москаленский муниципальный район'],
#  ['', 'мотыгинский район'],
#  ['', 'мошенской муниципальный район'],
#  [' новосибирской области', 'мошковский муниципальный район'],
#  ['', 'муезерский муниципальный район'],
#  ['', 'муйский район'],
#  ['', ' аларский район'],
#  ['республики саха (якутия)', ' алданский район '],
#  ['', ' баяндаевский район'],
#  ['', ' боханский район'],
#  ['', ' братский район'],
#  [' ленинградской области', ' гатчинский муниципальный район'],
#  ['', ' город адыгейск'],
#  ['', ' заларинский район'],
#  ['', ' казачинско-ленский район'],
#  ['', ' катангский район'],
#  ['', ' качугский район'],
#  ['', ' кингисеппский муниципальный район'],
#  ['республики саха (якутия)', ' ленский район '],
#  ['республики саха (якутия)', ' намский улус '],
#  ['', ' нижнеилимский район'],
#  ['', ' нижнеудинский район'],
#  ['', ' нукутский район'],
#  ['', ' осинский район'],
#  [' ленинградской области', ' подпорожский муниципальный район'],
#  ['', ' слюдянский район'],
#  [' владимирской области', ' судогодский район'],
#  ['', ' тахтамукайский район'],
#  ['', ' тулунский район'],
#  ['', ' эхирит-булагатский район'],
#  ['', ' город екатеринбург'],
#  ['', ' город саянск'],
#  ['', ' город свирск'],
#  ['', ' город черемхово'],
#  ['', ' посёлок уральский'],
#  [' ленинградской области', ' всеволожский муниципальный район'],
#  [' ленинградской области', ' выборгский район'],
#  ['', ' усть-илимский район'],
#  ['', ' - город тулун'],
#  ['', ' алапаевское'],
#  [' владимирской области', ' александровский район'],
#  [' кировской области', ' арбажский муниципальный округ'],
#  ['', ' балаганский район'],
#  ...]

# %%
len(mun_names)
# Out:
# 2170

# %%
test = pd.DataFrame()
test["region"] = list(map(lambda x: x[0], mun_names))
test["municipality"] = list(map(lambda x: x[1], mun_names))

# %%
matcher = Geomatch(standard_db=standard_df,
                  match_columns=['municipality', 'region'])

normaliser = Geonormaliser(standard_db=standard_df, 
                      use_speller=True,
                      use_levenstein=True,
                      match_columns=['municipality', 'region'])

# %%
test_norm = matcher(test)

# %%
test = test[["municipality", "region"]].rename(columns={"municipality": "mun_original", "region": "reg_original"})

# %%
matches = pd.concat([test, test_norm[["municipality", "region", "mun_type", "oktmo", "results_count"]]], axis=1)

# %%
matches.to_excel("matches.xlsx")
